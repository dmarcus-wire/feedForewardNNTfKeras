# %% [markdown]
# Import packages

# %%
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import classification_report
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.datasets import mnist
from tensorflow.keras import backend as K
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# CIFAR10

# %%
# load the training and testing data
# scale it to 0, 1
# reshape the design matrix

print ("[INFO] loading CIFAR-10 data...")
((trainX, trainY), (testX, testY)) = cifar10.load_data()
trainX = trainX.astype("float") / 255.0
testX = testX.astype("float") / 255.0
trainX = trainX.reshape((trainX.shape[0], 3072))
testX = testX.reshape((testX.shape[0], 3072))
# Out:
# [INFO] loading CIFAR-10 data...

# %% [markdown]
# Convert form labels to vectors

# %%
lb = LabelBinarizer()
trainY = lb.fit_transform(trainY)
testY = lb.transform(testY)

# initialize the label names for CIFAR-10 dataset
labelNames = ["airplane", "automobile", "bird", "cat", "deer", "dog",
              "frog", "horse", "ship", "truck"]

# %% [markdown]
# Model definition

# %%
model = Sequential()
model.add(Dense(1024, input_shape=(3072,), activation="relu"))
model.add(Dense(512, activation="relu"))
model.add(Dense(10, activation="softmax"))

# %% [markdown]
# Train model

# %%
# train the model using SGD
print("[INFO] training network...")
sgd = SGD(0.01)
model.compile(loss="categorical_crossentropy", optimizer=sgd,
	metrics=["accuracy"])
H = model.fit(trainX, trainY, validation_data=(testX, testY),
	epochs=100, batch_size=32)
# Out:
# [INFO] training network...
# Epoch 1/100
# 1563/1563 [==============================] - 29s 18ms/step - loss: 1.8395 - accuracy: 0.3430 - val_loss: 1.7106 - val_accuracy: 0.3824
# Epoch 2/100
# 1563/1563 [==============================] - 29s 18ms/step - loss: 1.6522 - accuracy: 0.4166 - val_loss: 1.6041 - val_accuracy: 0.4323
# Epoch 3/100
# 1563/1563 [==============================] - 32s 20ms/step - loss: 1.5702 - accuracy: 0.4457 - val_loss: 1.5487 - val_accuracy: 0.4523
# Epoch 4/100
#  - ETA: 8s - loss: 1.5172 - accuracy: 0.4648
# Epoch 5/100
# 1563/1563 [==============================] - 34s 22ms/step - loss: 1.4644 - accuracy: 0.4866 - val_loss: 1.5459 - val_accuracy: 0.4510
# Epoch 6/100
# 1563/1563 [==============================] - 34s 22ms/step - loss: 1.4250 - accuracy: 0.4975 - val_loss: 1.4569 - val_accuracy: 0.4766
# Epoch 7/100
# 1563/1563 [==============================] - 36s 23ms/step - loss: 1.3897 - accuracy: 0.5113 - val_loss: 1.5530 - val_accuracy: 0.4409
# Epoch 8/100
# 1563/1563 [==============================] - 32s 21ms/step - loss: 1.3565 - accuracy: 0.5235 - val_loss: 1.4530 - val_accuracy: 0.4731
# Epoch 9/100
# 1563/1563 [==============================] - 30s 19ms/step - loss: 1.3281 - accuracy: 0.5327 - val_loss: 1.4282 - val_accuracy: 0.4934
# Epoch 10/100
# 1563/1563 [==============================] - 30s 20ms/step - loss: 1.2955 - accuracy: 0.5471 - val_loss: 1.4655 - val_accuracy: 0.4746
# Epoch 11/100
# 1563/1563 [==============================] - 29s 18ms/step - loss: 1.2713 - accuracy: 0.5522 - val_loss: 1.3735 - val_accuracy: 0.5125
# Epoch 12/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.2429 - accuracy: 0.5623 - val_loss: 1.3566 - val_accuracy: 0.5228
# Epoch 13/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.2215 - accuracy: 0.5725 - val_loss: 1.5254 - val_accuracy: 0.4692
# Epoch 14/100
#  - ETA: 15s - loss: 1.1955 - accuracy: 0.5857
# Epoch 15/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.1750 - accuracy: 0.5865 - val_loss: 1.5350 - val_accuracy: 0.4767
# Epoch 16/100
# 1563/1563 [==============================] - 29s 18ms/step - loss: 1.1481 - accuracy: 0.5961 - val_loss: 1.3980 - val_accuracy: 0.5012
# Epoch 17/100
# 1563/1563 [==============================] - 31s 20ms/step - loss: 1.1277 - accuracy: 0.6033 - val_loss: 1.4126 - val_accuracy: 0.5085
# Epoch 18/100
# 1563/1563 [==============================] - 30s 19ms/step - loss: 1.1051 - accuracy: 0.6135 - val_loss: 1.3989 - val_accuracy: 0.5105
# Epoch 19/100
# 1563/1563 [==============================] - 31s 20ms/step - loss: 1.0858 - accuracy: 0.6200 - val_loss: 1.3445 - val_accuracy: 0.5312
# Epoch 20/100
# 1563/1563 [==============================] - 34s 22ms/step - loss: 1.0630 - accuracy: 0.6278 - val_loss: 1.3878 - val_accuracy: 0.5170
# Epoch 21/100
# 1563/1563 [==============================] - 30s 19ms/step - loss: 1.0424 - accuracy: 0.6363 - val_loss: 1.3287 - val_accuracy: 0.5315
# Epoch 22/100
# 1563/1563 [==============================] - 39s 25ms/step - loss: 1.0202 - accuracy: 0.6444 - val_loss: 1.6362 - val_accuracy: 0.4726
# Epoch 23/100
#  - ETA: 31s - loss: 1.0601 - accuracy: 0.6009
# Epoch 24/100
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.9798 - accuracy: 0.6586 - val_loss: 1.4210 - val_accuracy: 0.5110
# Epoch 25/100
# 1563/1563 [==============================] - 30s 19ms/step - loss: 0.9569 - accuracy: 0.6663 - val_loss: 1.4324 - val_accuracy: 0.5102
# Epoch 26/100
# 1563/1563 [==============================] - 30s 19ms/step - loss: 0.9344 - accuracy: 0.6718 - val_loss: 1.3143 - val_accuracy: 0.5461
# Epoch 27/100
# 1010/1563 [==================>...........] - ETA: 10s - loss: 0.9058 - accuracy: 0.6840

# %% [markdown]
# Evaluate model

# %%
# evaluate the network
print("[INFO] evaluating network...")
predictions = model.predict(testX, batch_size=32)
print(classification_report(testY.argmax(axis=1),
	predictions.argmax(axis=1), target_names=labelNames))

# %% [markdown]
# Visualize model performance

# %%
# plot the training loss and accuracy
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, 100), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, 100), H.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, 100), H.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, 100), H.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend()
plt.show()
